# %%
#Here's the datasets for submission

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YOUR-API-KEY")
project = rf.workspace("ongsa-23tub").project("lab8licenseplate")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=undefined&ref=undefined
# loading Roboflow workspace...
# ---------------------------------------------------------------------------
# RoboflowError                             Traceback (most recent call last)
# Cell In[1], line 5
#       3 from roboflow import Roboflow
#       4 rf = Roboflow(api_key="YOUR-API-KEY")
# ----> 5 project = rf.workspace("ongsa-23tub").project("lab8licenseplate")
#       6 version = project.version(1)
#       7 dataset = version.download("yolov11")
#
# File c:\Users\gifly\miniconda3\envs\AI_LAB\lib\site-packages\roboflow\__init__.py:238, in Roboflow.workspace(self, the_workspace)
#     236 if self.api_key:  # Check if api_key was passed during __init__
#     237     api_key = self.api_key
# --> 238     list_projects = rfapi.get_workspace(api_key, the_workspace)
#     239     return Workspace(list_projects, api_key, the_workspace, self.model_format)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r"D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\yolo11n.pt")  # load a pretrained model (recommended for training)
yaml_path = r"D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\Activity08\Lab8LicensePlate-1\data.yaml"
# Train the model
if __name__ == '__main__':
    #results = model.train(data=yaml_path, epochs=100, imgsz=640)
    model.tune(data=yaml_path, epochs=30, iterations=10
               , optimizer="AdamW", plots=False, save=False, val=False,patience=20,batch=16,lr0=1e-3)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\Activity08\runs\detect\tune'
# Tuner:  Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/10 with hyperparameters: {'lr0': 0.001, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'cutmix': 0.0, 'copy_paste': 0.0, 'close_mosaic': 10}
# Saved D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\Activity08\runs\detect\tune\tune_scatter_plots.png
# Saved D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\Activity08\runs\detect\tune\tune_fitness.png
#
# Tuner: 1/10 iterations complete  (580.56s)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r"D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\yolo11n.pt")  # load a pretrained model (recommended for training)
yaml_path = r"D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\Activity08\Lab8LicensePlate-1\data.yaml"
# Train the model
if __name__ == '__main__':
    results = model.train(data=yaml_path, epochs=100, imgsz=640,cfg=r'D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\Activity08\runs\detect\tune\best_hyperparameters.yaml')
    # model.tune(data=yaml_path, epochs=30, iterations=300
    #            , optimizer="AdamW", plots=False, save=False, val=False)
# Out:
# Ultralytics 8.4.21  Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# ...

# %%
# Load a model
model = YOLO(r"bestfromhp.pt")  # load a custom model

# Evaluate on validation or test dataset
metrics = model.val(
    data=r"D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\Activity08\Lab8LicensePlate-1\data.yaml",
    split = 'test',
    imgsz=640,
    batch=16,
    conf=0.25,
    iou=0.7,
    device="0"
)
# Out:
# Ultralytics 8.4.21  Python-3.10.19 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# YOLO11n summary (fused): 101 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 335.2182.3 MB/s, size: 53.3 KB)
# val: Scanning D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\Activity08\Lab8LicensePlate-1\test\labels.cache... 39 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 39/39  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.3s/it 6.9s2.1s2s
#                    all         39         48      0.864      0.771      0.865      0.714
# Speed: 12.1ms preprocess, 11.8ms inference, 0.0ms loss, 2.9ms postprocess per image
# Results saved to D:\3rd-Year\2nd semester\ComputerVision\ITCS351_L16\Activity08\runs\detect\val2
